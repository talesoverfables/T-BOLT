# %% [markdown]
# <a href="https://colab.research.google.com/github/talesoverfables/T-BOLT/blob/main/CV/Nr_ABVMCRI_Gate_FIX_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import locale
print(locale.getpreferredencoding)
# Out:
# <function getpreferredencoding at 0x7e59cb960ee0>

# %%
import locale
def getpreferredencoding(do_setlocale = True):
  return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# !scp "/content/gdrive/My Drive/cv/qwert/data.zip" "/content/data.zip"
# !unzip "/content/data.zip" -d "/content/"
# Out:
# Archive:  /content/data.zip
#   inflating: /content/data/val/images/labels/60.txt
#   inflating: /content/data/train/labels/30.txt
#   inflating: /content/data/train/labels/10.txt
#   inflating: /content/data/val/images/labels/59.txt
#   inflating: /content/data/val/labels/61.txt
#   inflating: /content/data/val/labels/59.txt
#   inflating: /content/data/val/images/labels/61.txt
#   inflating: /content/data/train/labels/12.txt
#   inflating: /content/data/val/labels/57.txt
#   inflating: /content/data/val/labels/58.txt
#   inflating: /content/data/val/images/labels/57.txt
#   inflating: /content/data/train/images/47.png
#   inflating: /content/data/train/images/49.png
#   inflating: /content/data/train/labels/43.txt
#   inflating: /content/data/train/labels/14.txt
#   inflating: /content/data/train/labels/41.txt
#   inflating: /content/data/val/images/labels/58.txt
#   inflating: /content/data/val/labels/60.txt
#   inflating: /content/data/train/labels/54.txt
# ...

# %%
# !git clone https://github.com/WongKinYiu/yolov9.git
# %cd yolov9
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 627, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 627 (delta 2), reused 1 (delta 0), pack-reused 621
# Receiving objects: 100% (627/627), 3.21 MiB | 8.23 MiB/s, done.
# Resolving deltas: 100% (241/241), done.
# /content/yolov9

# %%
# !pip install -r requirements.txt -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 12.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 38.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 36.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 61.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 12.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.2 MB/s eta 0:00:00
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# !mkdir -p {HOME}/weights

# %%
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt

# %%
# !ls -la {HOME}/weights
# Out:
# total 237676
# drwxr-xr-x  2 root root      4096 Apr  6 07:03 .
# drwxr-xr-x 13 root root      4096 Apr  6 07:02 ..
# -rw-r--r--  1 root root 103153312 Feb 18 12:36 yolov9-c.pt
# -rw-r--r--  1 root root 140217688 Feb 18 12:36 yolov9-e.pt

# %%
# !python train_dual.py --workers 8 --device 0 --batch 8 --data '/content/gdrive/My Drive/cv/qwert/data.yaml' --img 640 --cfg models/detect/yolov9-e.yaml --weights '{HOME}/weights/yolov9-e.pt' --name yolov9-e-finetuning --hyp hyp.scratch-high.yaml --min-items 0 --epochs 50 --close-mosaic 15
# Out:
# 2024-04-06 07:03:35.203220: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-06 07:03:35.203276: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-06 07:03:35.343006: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-06 07:03:36.862700: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# !scp "/content/gdrive/MyDrive/cv/qwert/video.mp4"  '/content/video.mp4'

# %%
  f!python detect_dual.py --source '/content/video.mp4' --img 640 --device 0 --weights '/content/yolov9/runs/train/yolov9-e-finetuning/weights/best.pt' --name yolov9_ppe_640_detect --vid-stride 4
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (6324/11322) /content/video.mp4: 384x640 2 wrong parkings, 13 footpath encroachments, 50.3ms
# video 1/1 (6325/11322) /content/video.mp4: 384x640 1 wrong parking, 13 footpath encroachments, 46.3ms
# video 1/1 (6326/11322) /content/video.mp4: 384x640 1 wrong parking, 13 footpath encroachments, 42.6ms
# video 1/1 (6327/11322) /content/video.mp4: 384x640 1 wrong parking, 13 footpath encroachments, 62.7ms
# video 1/1 (6328/11322) /content/video.mp4: 384x640 1 wrong parking, 13 footpath encroachments, 50.7ms
# video 1/1 (6329/11322) /content/video.mp4: 384x640 1 wrong parking, 13 footpath encroachments, 54.9ms
# video 1/1 (6330/11322) /content/video.mp4: 384x640 1 wrong parking, 13 footpath encroachments, 54.8ms
# video 1/1 (6331/11322) /content/video.mp4: 384x640 1 wrong parking, 13 footpath encroachments, 69.0ms
# video 1/1 (6332/11322) /content/video.mp4: 384x640 1 wrong parking, 13 footpath encroachments, 78.7ms
# ...

# %%
#from google.colab import drive
#drive.mount('/content/gdrive')
#
#!cp /content/yolov9/runs/detect/yolov9_ppe_640_detect/video.mp4 /content/gdrive/MyDrive

# %%
import shutil
shutil.copy("/content/yolov9/runs/detect/yolov9_ppe_640_detect/video.mp4", "/content/gdrive/MyDrive")
# Out:
# '/content/gdrive/MyDrive/video.mp4'
